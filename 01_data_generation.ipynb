# %%
import pandas as pd

data = r"C:\Users\henri-philippe.konan\Desktop\Perso\Devenir data scientist\Portfolio repo Github\CNTS_forecasting_poc\cnts_simulated_blood_demand.csv"
df = pd.read_csv(data)

df.head()
# Out:
#      month   region blood_group  hospital_demand_units  collected_units  \
# 0  2023-01  Abidjan          O+                    532              527
# 1  2023-01  Abidjan          A+                    347              358
# 2  2023-01  Abidjan          B+                    271              257
# 3  2023-01  Abidjan         AB+                     91               68
# 4  2023-01  Abidjan          O-                     59               46
#
#    available_stock_units  expired_units           season  shortage_flag  \
# 0                    693              7  fêtes/accidents              0
# 1                    422              4  fêtes/accidents              0
# 2                    286              5  fêtes/accidents              0
# 3                     86              2  fêtes/accidents              1
# 4                     51              1  fêtes/accidents              1
#
#    coverage_ratio risk_level
# 0            1.30     Faible
# 1            1.22     Faible
# ...

# %%
df["season"].value_counts().sort_values(ascending=False)
# Out:
# season
# normal             600
# paludisme          600
# fêtes/accidents    240
# Name: count, dtype: int64

# %%
df["shortage_flag"].value_counts().sort_values(ascending=False)
# Out:
# shortage_flag
# 1    1177
# 0     263
# Name: count, dtype: int64

# %%
df["blood_group"].value_counts().sort_values(ascending=False)
# Out:
# blood_group
# O+     180
# A+     180
# B+     180
# AB+    180
# O-     180
# A-     180
# B-     180
# AB-    180
# Name: count, dtype: int64

# %%
df["risk_level"].value_counts().sort_values(ascending=False)
# Out:
# risk_level
# Élevé     899
# Moyen     370
# Faible    171
# Name: count, dtype: int64

# %%
df.shape
# Out:
# (1440, 11)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1440 entries, 0 to 1439
# Data columns (total 11 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   month                  1440 non-null   object
#  1   region                 1440 non-null   object
#  2   blood_group            1440 non-null   object
#  3   hospital_demand_units  1440 non-null   int64
#  4   collected_units        1440 non-null   int64
#  5   available_stock_units  1440 non-null   int64
#  6   expired_units          1440 non-null   int64
#  7   season                 1440 non-null   object
#  8   shortage_flag          1440 non-null   int64
#  9   coverage_ratio         1440 non-null   float64
#  10  risk_level             1440 non-null   object
# dtypes: float64(1), int64(5), object(5)
# memory usage: 123.9+ KB

# %%
df.describe(include="all").T
# Out:
#                         count unique      top freq       mean         std  \
# month                    1440     36  2023-01   40        NaN         NaN
# region                   1440      5  Abidjan  288        NaN         NaN
# blood_group              1440      8       O+  180        NaN         NaN
# hospital_demand_units  1440.0    NaN      NaN  NaN  75.404167  112.851827
# collected_units        1440.0    NaN      NaN  NaN  62.496528   103.04714
# available_stock_units  1440.0    NaN      NaN  NaN  72.855556  125.575705
# expired_units          1440.0    NaN      NaN  NaN   1.399306     2.80318
# season                   1440      3   normal  600        NaN         NaN
# shortage_flag          1440.0    NaN      NaN  NaN   0.817361    0.386504
# coverage_ratio         1440.0    NaN      NaN  NaN   0.783083    0.212117
# risk_level               1440      3    Élevé  899        NaN         NaN
#
#                         min   25%   50%   75%    max
# ...

# %%
df.isna().sum()
# Out:
# month                    0
# region                   0
# blood_group              0
# hospital_demand_units    0
# collected_units          0
# available_stock_units    0
# expired_units            0
# season                   0
# shortage_flag            0
# coverage_ratio           0
# risk_level               0
# dtype: int64

# %%
df.dtypes
# Out:
# month                     object
# region                    object
# blood_group               object
# hospital_demand_units      int64
# collected_units            int64
# available_stock_units      int64
# expired_units              int64
# season                    object
# shortage_flag              int64
# coverage_ratio           float64
# risk_level                object
# dtype: object

# %%
df.nunique()
# Out:
# month                     36
# region                     5
# blood_group                8
# hospital_demand_units    275
# collected_units          254
# available_stock_units    269
# expired_units             23
# season                     3
# shortage_flag              2
# coverage_ratio           102
# risk_level                 3
# dtype: int64

# %% [markdown]
# ![image.png](attachment:image.png)
